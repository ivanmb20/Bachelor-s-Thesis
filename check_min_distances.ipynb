# %%
#Importación de librerías

import numpy as np
import numba as nb
import math as m
import matplotlib
import matplotlib.pyplot as plt
#matplotlib.use('notebook')  # or 'notebook', 'agg', etc.
from matplotlib.animation import FuncAnimation
import matplotlib.patches as patches
from numba import float32,float64, guvectorize 
import csv

# %%
#  Definición de parámetros

h = 0.0001 
boxSide = 91.8
cuadrantLength = boxSide*0.5
totalSteps = 10000 
frameIterSep = 100

G = 160330.0 * 818.9 
H = 160330.0 
p = 13 
q = 7 
damp = 0.75 
v_tapa = -40.0 
vp = 6.23 
eps=1e-6

rInt = np.float64(3.39)
rMin = np.float64(2.25) 
softFactor = 0.001

# %%
# Configuración de los bloques de partículas
### ------- La configuración se adecua a lo que el usuario requiera ---------

row1_part = int(31) # 31 
row1_dx = 3.06
row2_part = int(30)
row2_dx = 3.06
rows_dy = 2.65
blockParticles = int(61) # 31 +30
totalParticles = int(1068)

# %%
@nb.guvectorize([(float64[:], float64[:], float64[:])],
    '(n), (n) -> (n)',
    nopython=True,
    target='parallel'
)

# COmpute forces between two particles
def pairwise_lennarJonnes_gu(body1:np.ndarray[np.float64], body2:np.ndarray[np.float64], outForce:np.ndarray[np.float64]):
    x1, y1 = body1[0], body1[1]
    x2, y2 = body2[0], body2[1]
    dx = x2 - x1
    dy = y2 - y1
    r2 = dx*dx + dy*dy

    r = np.sqrt(r2)

    if r < eps or r > rInt: 
        outForce[0] = 0.0
        outForce[1] = 0.0
        return

    vunit_x = dx/r
    vunit_y = dy/r
    upperPot = -G

    i = 1
    dist = np.float64(1.0)

    if r < rMin:
        r = rMin

    dist *= r
    while i < p - q: # Se puede omitir el while calculando la potencia directamente
        i+=1
        dist *= r

    upperPot += H*dist

    while i<p:
        i+=1
        dist *= r
        
    outForce[0] = vunit_x*upperPot/dist
    outForce[1] = vunit_y*upperPot/dist
    return

    """
    # Extrae las coordenadas x e y de cuerpo 1 y 2
    x1, y1 = body1[0], body1[1]
    x2, y2 = body2[0], body2[1]
    # Saca la dirección del vector unitario x e y
    dx = x1 - x2
    dy = y1 - y2
    r2 = dx*dx + dy*dy

    r = np.sqrt(r2) 

    # Condición para asegurar que la distancia mínima posible entre partículas sea rInt (al graficar, rInt acota un valor determinado de A)
    if r<rMin:
        r=rMin

    if r > rInt: # Condición que asegura si la distancia al cuadrado es menor a 1e-12 es que la distancia es pequeñísima
        outForce[0] = 0.0
        outForce[1] = 0.0
        return
    
    # Vector unitario en dirección j->i
    vunit_x = dx/r
    vunit_y = dy/r

    # Magnitud
    mag= (-G / (r**2)) + (H / (r**q))

    # vector unitario (dx/r, dy/r) multiplicado por magnitud
    outForce[0] = mag * vunit_x
    outForce[1] = mag * vunit_y

    return
    """

# Computes the net forces for all i and all j
def compute_net_forces_parallel(bodies):
    """Computes the net gravitational force on each body using guvectorize."""
    num_bodies = bodies.shape[0]
    forces = np.zeros((num_bodies, 2), dtype=np.float64)

    for i in range(num_bodies):
    # Calculate forces exerted by all other bodies on body i
        other_bodies = np.delete(bodies, i, axis=0)
        assert other_bodies.shape[0] == (num_bodies-1) and other_bodies.shape[1]==2, "Error, no se eliminó nada, auxilio!\n"
        current_body = np.tile(bodies[i], (num_bodies-1, 1)) # Current_body is a (num_bodies-1,1) array 
        # Reshape for guvectorize
        #current_body = bodies[i]

        forces_on_i = pairwise_lennarJonnes_gu(
            current_body, other_bodies, np.zeros_like(other_bodies)
        )
        forces[i, :] = np.sum(forces_on_i, axis=0)

    return forces

@nb.guvectorize([(float64[:],float64[:],float64[:],float64[:])],
    '(n),(n) -> (n),(n)',
    target='parallel',
    nopython=True
)

def fitInsideParticle(position,velocity,newPosition,newVelocity):
    newPosition[0]=position[0]
    newPosition[1]=position[1]
    newVelocity[0]=velocity[0]
    newVelocity[1]=velocity[1]

    #marginError=np.float64(1e-6)

    if((-cuadrantLength < newPosition[0] and newPosition[0] < cuadrantLength)
        and (0 < newPosition[1] and newPosition[1] < boxSide)):
        return
    contCycles = 0
    isInside = False

    while not(isInside) and contCycles < 25: # Número de ciclos máximos para checar que las part están dentro de la caja
        contCycles += 1

        # Partícula se sale por la izquierda
        if( - cuadrantLength > newPosition[0] ):
            newPosition[0] = -2.0*cuadrantLength - newPosition[0]
            newVelocity[0] *= -damp
            # Vy es tangente a la pared
            newVelocity[1] *= 0.0

        # Partícula se sale por abajo
        if( newPosition[1] < 0):
            newPosition[1] = -newPosition[1]
            # Vx es tangente a la pared
            newVelocity[0] *= 0.0
            newVelocity[1] *= -damp

        # Partícula se sale por la derecha    
        if( cuadrantLength < newPosition[0] ):
            newPosition[0] = 2.0*cuadrantLength - newPosition[0]
            newVelocity[0] *= -damp
            newVelocity[1] *= 0.0

        # Partícula se sale por arriba
        if( boxSide < newPosition[1] ):
            newPosition[1] = 2.0*boxSide - newPosition[1]
            newVelocity[0] = newVelocity[0]*damp + v_tapa
            newVelocity[1] = -newVelocity[1]*damp

        # Partícula está dentro de la caja
        if((-cuadrantLength < newPosition[0] and newPosition[0] < cuadrantLength)
            and (0 < newPosition[1] and newPosition[1] < boxSide)):
            isInside = True
        
    return


@nb.guvectorize(
        '(float64[:], float64[:], float64, float64[:])',
        '(n),(n),() -> (n)',
        target='parallel',
        nopython=True
)
def integration(yn, dy, hstep, y):
    y[0] = yn[0] + hstep*dy[0]
    y[1] = yn[1] + hstep*dy[1]
    return


def getInitialPositions(firsRowPos:tuple, secondRowPos:tuple, sepX:float|np.float64, sepY:float|np.float64
                        , numFirstRow:int, N:int):
    
    positions = np.zeros((N, 2),dtype=np.float64) # Arreglo Nx2 dimensional
    blockP = int(2*numFirstRow - 1) # Bloque de partículas por cada dos filas

    firsRowPos = np.array(firsRowPos, dtype=np.float64)
    secondRowPos = np.array(secondRowPos, dtype=np.float64)
    sepX = np.float64(sepX)
    sepY = np.float64(sepY)


    positions[0] = firsRowPos
    for i in range(1, numFirstRow):
        positions[i][0] = positions[i-1][0] + sepX
        positions[i][1] = positions[i-1][1]

    positions[numFirstRow] = secondRowPos
    
    for i in range(numFirstRow+1, blockP):
        positions[i][0] = positions[i-1][0] + sepX
        positions[i][1] = positions[i-1][1]

    for i in range(blockP, N):
        positions[i][0] = positions[i-blockP][0]
        positions[i][1] = positions[i-blockP][1] + 2.0*sepY

    return positions

def getInitialVelocities(v0, N):
    angles = np.random.uniform(-np.pi,np.pi,N)
    velocities = v0*np.transpose([np.cos(angles), np.sin(angles)])
    return velocities

# %%
tres_seisp=np.float64(3.06)
tres_seisn=np.float64(-3.06)

tres_seisp+tres_seisn
# Out:
# 0.0

# %%
if __name__ == '__main__':
    # Ejemplo de uso:
    import time
    num_bodies = totalParticles
    hstep = h

    # Obtén posición inicial
    bodies_dataX = getInitialPositions((-cuadrantLength, 0.0), (-cuadrantLength + row1_dx*0.5, rows_dy),\
            row1_dx, rows_dy, row1_part, num_bodies)

    # Obtén velocidad inicial
    bodies_dataV = getInitialVelocities(vp, num_bodies)

    # Obtén las aceleraciones en función de las posiciones (Recordemos que la fuerza, ergo la aceleración está solo en función de la posición)
    bodies_dataA = compute_net_forces_parallel(bodies_dataX)

    startIndex=0
    
    print("Forma de la información de X: ",bodies_dataX.shape)
    print("Forma de la información de V: ",bodies_dataV.shape)
    print("Forma de la información de V: ",bodies_dataV.shape)

    startIndex = startIndex*frameIterSep

    velocidades = np.sqrt(bodies_dataV[:,0]**2 + bodies_dataV[:,1]**2)
    velocidadPromedio = (1.0/num_bodies)*np.sum(velocidades)
    
    #print("Energia promedio del sistema: ", (3.0103e-24)*velocidadPromedio, " Joules.")
    # De donde sale el cálculo de esta energia promedio?

    ### Aqui hacemos una mascara, en particular queremos ver quienes son las que son particulas muy rapidas
    mask = velocidades>=0.9*velocidadPromedio
    elementosRapidosX = []
    elementosRapidosV = []
    magnitude = []

    for i in range(len(mask)):
        if mask[i]:
            elementosRapidosX.append(bodies_dataX[i])
            elementosRapidosV.append(bodies_dataV[i])
            magnitude.append(velocidades[i])
    index = int(0)
    filename = 'C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/'+ str(index)+'.png'

    # Transformar elementosRapidos a un array por la eficiencia de cálculos
    elementosRapidosV = np.array(elementosRapidosV, dtype=np.float64)
    elementosRapidosX = np.array(elementosRapidosX, dtype=np.float64)

    
    #plt.style.use('dark_background')
    plt.figure(figsize=(16, 16))
    # Se dibujan las paredes del contenedor
    plt.plot([-boxSide/2.0, boxSide/2.0], [0.0, 0.0], color='k')
    plt.plot([boxSide/2.0, boxSide/2.0], [0.0, boxSide], color='k')
    plt.plot([boxSide/2.0, -boxSide/2.0], [boxSide, boxSide], color='k')
    plt.plot([-boxSide/2.0, -boxSide/2.0], [boxSide, 0.0], color='k')
    # Se dibujan las partículas que cumplen la condición de ser rápidas
    plt.quiver(elementosRapidosX[:,0], elementosRapidosX[:,1],
                elementosRapidosV[:,0], elementosRapidosV[:,1],
                magnitude, cmap='viridis')
    plt.colorbar(label='Velocidad (Angstroms/ps)')
    plt.xlabel("X-axis (Angstroms)")
    plt.ylabel("Y-axis (Angstroms)")
    plt.title(f"Simulacion al tiempo {startIndex*h} ps. Particulas veloces")
    plt.savefig(filename)
    plt.clf()
    print("\n")
    
    key_steps=[2500,5000,7500]
    key_steps=np.array(key_steps)
    key_hiter=key_steps/frameIterSep
    jota=2000
    
    # Action Items:
    # 1. Sacar la aceleración promedio de todas las partículas en cada frame e irlas imprimiendo y guardarlas en un archivo .csv
    # 2. Crear la función de las distancias como lo explico leo, con un arreglo numpy de la distancia euclidiana de todas las particulas con respecto a su posición anterior
    # 3. Seguir variando el rMin para ver como cambia la dinámica del sistema
    # 4. Tratar de paralelizar el código con numba en el nuevo visual studio code para developers con cuda apis
    # 5. Volver a sacar las ráfagas de frames con PIV y ver si ahora no saca vectores outliers

    # Guardar los datos en archivos binarios
    with open('C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/serialPositions.bin', 'wb') as sp:
        with open('C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/serialVelocities.bin', 'wb') as sv:
            with open('C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/serialTime.bin', 'wb') as st:
                # Arreglo para guardar posiciones y compararlas, se usa para calcular la velocidad promedio J
                pos_guardadas=[]

                frames = 0
                st.write(np.float64(0.0).tobytes())
                sp.write(bodies_dataX.tobytes())
                sv.write(bodies_dataV.tobytes())
                #ahora calculo
                bodies_dataA = compute_net_forces_parallel(bodies_dataX)

                for s in range(startIndex,totalSteps):
                    pos_guardadas.append(np.copy(bodies_dataX))

                    if frames%frameIterSep == 0:
                        st.write(np.float64(s*hstep).tobytes())
                        sp.write(bodies_dataX.tobytes())
                        sv.write(bodies_dataV.tobytes())
                        print("Tiempo actual en la simulacion! : ", (s*hstep))
                        print("Maximo valor en la aceleracion: ", (np.max(bodies_dataA[:,0]**2 + bodies_dataA[:,1]**2)))
                        print("Minimo valor en la aceleracion: ", (np.min(bodies_dataA[:,0]**2 + bodies_dataA[:,1]**2)))
                        
                        velocidades = np.sqrt(bodies_dataV[:,0]**2 + bodies_dataV[:,1]**2)
                        velocidadPromedio = (1.0/num_bodies)*np.sum(velocidades)
                        print("Energia promedio del sistema: ", (3.0103e-24)*velocidadPromedio, " Joules.")

                        ### Aqui hacemos una mascara, en particular queremos ver quienes son las que son particulas muy rapidas
                        mask = velocidades>=0.9*velocidadPromedio
                        elementosRapidosX = []
                        elementosRapidosV = []
                        magnitude = []

                        for i in range(len(mask)):
                            if mask[i]: # Si la mascara es verdad, eso significa que hay una velocidad que si cumple ser mayor que la promedio
                                elementosRapidosX.append(bodies_dataX[i])
                                elementosRapidosV.append(bodies_dataV[i])
                                magnitude.append(velocidades[i])
                        index = s
                        filename = 'C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/'+ str(index)+'.png'

                        elementosRapidosV = np.array(elementosRapidosV, dtype=np.float64)
                        elementosRapidosX = np.array(elementosRapidosX, dtype=np.float64)

                        plt.plot([-boxSide/2.0, boxSide/2.0], [0.0, 0.0], color='k')
                        plt.plot([boxSide/2.0, boxSide/2.0], [0.0, boxSide], color='k')
                        plt.plot([boxSide/2.0, -boxSide/2.0], [boxSide, boxSide], color='k')
                        plt.plot([-boxSide/2.0, -boxSide/2.0], [boxSide, 0.0], color='k')
                        plt.quiver(elementosRapidosX[:,0], elementosRapidosX[:,1],
                                        elementosRapidosV[:,0], elementosRapidosV[:,1],
                                        magnitude, cmap='viridis')
                        plt.colorbar(label='Velocidad (Angstroms/ps)')
                        plt.xlabel("X-axis (Angstroms)")
                        plt.ylabel("Y-axis (Angstroms)")
                        plt.title(f"Simulacion al tiempo {hstep*s} ps. Particulas veloces")
                        plt.savefig(filename)
                        plt.clf()
                        print("\n")

                        # Save the data in a csv file 
                        csv_path = r"C:/Users/ivan_/Desktop/Tesis/Python_scripts/Jupyter/V40/Testing/data_csv.csv"
                        # Escribe los datos en un csv para ir comparando las aceleraciones
                        with open(csv_path, 'a', newline='') as csvfile:
                            writer = csv.writer(csvfile)
                            header = ['Particle index','Time', 'PosX', 'PosY', 'VelX', 'VelY', 'AccX', 'AccY']
                            writer.writerow(header)
                            for i in range(num_bodies):
                                row = [i,frames*hstep, bodies_dataX[i,0], bodies_dataX[i,1], bodies_dataV[i,0], bodies_dataV[i,1], bodies_dataA[i,0], bodies_dataA[i,1]]
                                writer.writerow(row)

                    # Aquí aplica el paso de Leapfrog
                    bodies_dataV = bodies_dataV + 0.5*hstep*bodies_dataA
                    bodies_dataX = bodies_dataX + hstep*bodies_dataV
                    # Checa si al actualizar posición y velocidad, las partículas siguen dentro de la caja
                    bodies_dataX, bodies_dataV = fitInsideParticle(bodies_dataX, bodies_dataV, np.zeros_like(bodies_dataX), np.zeros_like(bodies_dataV))
                    # Calcula las nuevas aceleraciones
                    bodies_dataA = compute_net_forces_parallel(bodies_dataX)
                    bodies_dataV = bodies_dataV + 0.5*hstep*bodies_dataA

                    
                    frames += 1
                                    
                st.write(np.float64(totalSteps*hstep).tobytes())
                sp.write(bodies_dataX.tobytes())
                sv.write(bodies_dataV.tobytes())
                pass

    # Time the parallel execution
    start_time = time.time()
    bodies_dataA = compute_net_forces_parallel(bodies_dataX)
    end_time = time.time()
    print(f"Time taken with guvectorize (parallel): {end_time - start_time:.6f} seconds")
# Out:
# Forma de la información de X:  (1068, 2)
# Forma de la información de V:  (1068, 2)
# Forma de la información de V:  (1068, 2)
#
#
# Tiempo actual en la simulacion! :  0.0
# Maximo valor en la aceleracion:  0.10121637266427197
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.8754169000000004e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.01
# Maximo valor en la aceleracion:  2957.096673610954
# Minimo valor en la aceleracion:  0.11886301822566915
# Energia promedio del sistema:  1.8085698236761957e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.02
# Maximo valor en la aceleracion:  16463.45242687876
# Minimo valor en la aceleracion:  2.02269031975941
# Energia promedio del sistema:  1.6967321054943183e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.030000000000000002
# Maximo valor en la aceleracion:  51169.77521703682
# Minimo valor en la aceleracion:  9.896546374402481
# Energia promedio del sistema:  1.4919534346841147e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.04
# Maximo valor en la aceleracion:  95784.33406376708
# Minimo valor en la aceleracion:  13.864369081844087
# Energia promedio del sistema:  1.213157745952037e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.05
# Maximo valor en la aceleracion:  101882.40761588966
# Minimo valor en la aceleracion:  17.26439859639675
# Energia promedio del sistema:  9.991374934487167e-24  Joules.
#
#
# Tiempo actual en la simulacion! :  0.060000000000000005
# Maximo valor en la aceleracion:  69788.15391781805
# Minimo valor en la aceleracion:  3.8359221592698343
# Energia promedio del sistema:  1.0279850360443253e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.07
# Maximo valor en la aceleracion:  47444.930646895635
# Minimo valor en la aceleracion:  3.866904282980663
# Energia promedio del sistema:  1.1398329476591656e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.08
# Maximo valor en la aceleracion:  65486.82888173683
# Minimo valor en la aceleracion:  6.749902907902905
# Energia promedio del sistema:  1.212228233347173e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.09000000000000001
# Maximo valor en la aceleracion:  121566.39396283221
# Minimo valor en la aceleracion:  5.054819300426116
# Energia promedio del sistema:  1.21939741611153e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.1
# Maximo valor en la aceleracion:  134153.26339372506
# Minimo valor en la aceleracion:  15.29277467685723
# Energia promedio del sistema:  1.1857386630659836e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.11
# Maximo valor en la aceleracion:  136336.203456762
# Minimo valor en la aceleracion:  2.364490443686992
# Energia promedio del sistema:  1.1544635703336096e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.12000000000000001
# Maximo valor en la aceleracion:  104781.39205134127
# Minimo valor en la aceleracion:  3.898480202767227
# Energia promedio del sistema:  1.1407459627395258e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.13
# Maximo valor en la aceleracion:  140020.8788804697
# Minimo valor en la aceleracion:  0.16416479808188653
# Energia promedio del sistema:  1.1389105205261184e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.14
# Maximo valor en la aceleracion:  143037.60444668683
# Minimo valor en la aceleracion:  4.1760961365714975
# Energia promedio del sistema:  1.1483506748492616e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.15
# Maximo valor en la aceleracion:  129508.3893674548
# Minimo valor en la aceleracion:  4.71061571024455
# Energia promedio del sistema:  1.1623026984491642e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.16
# Maximo valor en la aceleracion:  162321.1406799366
# Minimo valor en la aceleracion:  0.8939154524309239
# Energia promedio del sistema:  1.1703490709019357e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.17
# Maximo valor en la aceleracion:  129962.87887201415
# Minimo valor en la aceleracion:  3.2254479057629135
# Energia promedio del sistema:  1.1733246134703293e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.18000000000000002
# Maximo valor en la aceleracion:  143451.83817466555
# Minimo valor en la aceleracion:  11.04112411166151
# Energia promedio del sistema:  1.1704087384050828e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.19
# Maximo valor en la aceleracion:  150479.35069994023
# Minimo valor en la aceleracion:  1.578561932481089
# Energia promedio del sistema:  1.1530857197253318e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.2
# Maximo valor en la aceleracion:  247986.22234818278
# Minimo valor en la aceleracion:  3.624240850477809
# Energia promedio del sistema:  1.1412894302135976e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.21000000000000002
# Maximo valor en la aceleracion:  170946.29776511673
# Minimo valor en la aceleracion:  1.5974553866851173
# Energia promedio del sistema:  1.1414115729949813e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.22
# Maximo valor en la aceleracion:  209728.1604294727
# Minimo valor en la aceleracion:  2.0244036920655293
# Energia promedio del sistema:  1.1522077457986724e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.23
# Maximo valor en la aceleracion:  142492.97956073264
# Minimo valor en la aceleracion:  1.291894152760205
# Energia promedio del sistema:  1.1764527385522474e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.24000000000000002
# Maximo valor en la aceleracion:  404571.3385430929
# Minimo valor en la aceleracion:  2.449952580177313
# Energia promedio del sistema:  1.1829725090806842e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.25
# Maximo valor en la aceleracion:  7872036.099367796
# Minimo valor en la aceleracion:  0.6741494491915032
# Energia promedio del sistema:  1.1863415384829734e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.26
# Maximo valor en la aceleracion:  558999.8342217784
# Minimo valor en la aceleracion:  0.3218652744072697
# Energia promedio del sistema:  1.1845304319280592e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.27
# Maximo valor en la aceleracion:  453257.4008221302
# Minimo valor en la aceleracion:  7.584638045834245
# Energia promedio del sistema:  1.1819634115040524e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.28
# Maximo valor en la aceleracion:  5146830.587863337
# Minimo valor en la aceleracion:  12.575208625864747
# Energia promedio del sistema:  1.1815359649542653e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.29000000000000004
# Maximo valor en la aceleracion:  959372.8189724277
# Minimo valor en la aceleracion:  15.473546325510597
# Energia promedio del sistema:  1.1953699239307836e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.3
# Maximo valor en la aceleracion:  913946.015718971
# Minimo valor en la aceleracion:  8.76358290817823
# Energia promedio del sistema:  1.2104074035571513e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.31
# Maximo valor en la aceleracion:  9358294.901011605
# Minimo valor en la aceleracion:  1.0941715980941689
# Energia promedio del sistema:  1.212076328372214e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.32
# Maximo valor en la aceleracion:  8483664.068474859
# Minimo valor en la aceleracion:  3.321030422727558
# Energia promedio del sistema:  1.2475903632563068e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.33
# Maximo valor en la aceleracion:  8582232.35076036
# Minimo valor en la aceleracion:  1.5023783447321784
# Energia promedio del sistema:  1.2576183362779334e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.34
# Maximo valor en la aceleracion:  8218487.656189285
# Minimo valor en la aceleracion:  0.6802613359204417
# Energia promedio del sistema:  1.2918172160377914e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.35000000000000003
# Maximo valor en la aceleracion:  6193074.4039304685
# Minimo valor en la aceleracion:  2.9781826554662945
# Energia promedio del sistema:  1.3196502400638026e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.36000000000000004
# Maximo valor en la aceleracion:  8587882.648396863
# Minimo valor en la aceleracion:  3.514876241537195
# Energia promedio del sistema:  1.3073952169361108e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.37
# Maximo valor en la aceleracion:  8578920.96435298
# Minimo valor en la aceleracion:  2.5609659856460887
# Energia promedio del sistema:  1.3482900341758428e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.38
# Maximo valor en la aceleracion:  7792738.419337999
# Minimo valor en la aceleracion:  1.037885570383001
# Energia promedio del sistema:  1.4002380367308926e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.39
# Maximo valor en la aceleracion:  8530898.942010341
# Minimo valor en la aceleracion:  1.6270154311368763
# Energia promedio del sistema:  1.4450132571070577e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.4
# Maximo valor en la aceleracion:  11946091.276626661
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.5273275326308914e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.41000000000000003
# Maximo valor en la aceleracion:  8529477.293328634
# Minimo valor en la aceleracion:  0.770335435893125
# Energia promedio del sistema:  1.5720066666390335e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.42000000000000004
# Maximo valor en la aceleracion:  11432645.868913133
# Minimo valor en la aceleracion:  3.5968090539542614
# Energia promedio del sistema:  1.5830641698976274e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.43
# Maximo valor en la aceleracion:  10576975.171167124
# Minimo valor en la aceleracion:  0.5692459671912108
# Energia promedio del sistema:  1.5998815902337602e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.44
# Maximo valor en la aceleracion:  8517551.974695344
# Minimo valor en la aceleracion:  8.155277117695722
# Energia promedio del sistema:  1.6521445883779846e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.45
# Maximo valor en la aceleracion:  13903438.453906598
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.687261668287847e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.46
# Maximo valor en la aceleracion:  32657957.734610874
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.717953158923556e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.47000000000000003
# Maximo valor en la aceleracion:  28016595.04005619
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.7991920898843136e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.48000000000000004
# Maximo valor en la aceleracion:  14057753.417990798
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.8553254428227528e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.49000000000000005
# Maximo valor en la aceleracion:  18412812.11808559
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.9076409570145062e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.5
# Maximo valor en la aceleracion:  13525674.35578385
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.9255820129857792e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.51
# Maximo valor en la aceleracion:  20006036.460850865
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  1.9525074698771716e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.52
# Maximo valor en la aceleracion:  32318872.674698923
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.0187522791928615e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.53
# Maximo valor en la aceleracion:  15095642.382158041
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.0874714986069584e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.54
# Maximo valor en la aceleracion:  14538147.025854986
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.159120386724402e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.55
# Maximo valor en la aceleracion:  20121557.69272362
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.1843650993771404e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.56
# Maximo valor en la aceleracion:  12185039.759993663
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.2240972350848525e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.5700000000000001
# Maximo valor en la aceleracion:  37464798.87445842
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.272586829751374e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.5800000000000001
# Maximo valor en la aceleracion:  30651796.795904998
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.3375264806703306e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.5900000000000001
# Maximo valor en la aceleracion:  11330689.927377215
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.4277131572313414e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.6
# Maximo valor en la aceleracion:  10430194.727014637
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.482365005767689e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.61
# Maximo valor en la aceleracion:  21992913.628922567
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.5569835201040968e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.62
# Maximo valor en la aceleracion:  28121212.554161675
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.581346894758528e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.63
# Maximo valor en la aceleracion:  31677546.315215968
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.621771294646267e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.64
# Maximo valor en la aceleracion:  27230077.807909146
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.6673851860698447e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.65
# Maximo valor en la aceleracion:  48774225.33927706
# Minimo valor en la aceleracion:  6.018239620773258
# Energia promedio del sistema:  2.623246367946939e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.66
# Maximo valor en la aceleracion:  92554280.82952061
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.6440394073266068e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.67
# Maximo valor en la aceleracion:  75988054.45236866
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.675402995704457e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.68
# Maximo valor en la aceleracion:  126314377.19980751
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.6855832171055326e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.6900000000000001
# Maximo valor en la aceleracion:  190241034.33699983
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.647056285166529e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.7000000000000001
# Maximo valor en la aceleracion:  135285248.61265105
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.7009285803275054e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.7100000000000001
# Maximo valor en la aceleracion:  77411428.7807083
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.7650177895529954e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.7200000000000001
# Maximo valor en la aceleracion:  76526995.51755437
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.7594097205361275e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.73
# Maximo valor en la aceleracion:  76564598.43408023
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.779296969935807e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.74
# Maximo valor en la aceleracion:  76528675.17172623
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.853900686628737e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.75
# Maximo valor en la aceleracion:  62373017.38904126
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.9085227570462224e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.76
# Maximo valor en la aceleracion:  148134040.6685305
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.8973927934385684e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.77
# Maximo valor en la aceleracion:  117600493.31267428
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.903303801284067e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.78
# Maximo valor en la aceleracion:  130338349.0425764
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.905069018722961e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.79
# Maximo valor en la aceleracion:  208487356.40010276
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.935554721453639e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.8
# Maximo valor en la aceleracion:  212926049.49379668
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.905358991085955e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.81
# Maximo valor en la aceleracion:  198294813.05794203
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.92496959807394e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.8200000000000001
# Maximo valor en la aceleracion:  162852709.1343408
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.937919517504791e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.8300000000000001
# Maximo valor en la aceleracion:  207634464.79063126
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  2.9548958957018775e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.8400000000000001
# Maximo valor en la aceleracion:  212346220.29741412
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.0464606071338744e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.8500000000000001
# Maximo valor en la aceleracion:  236796268.63749418
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.0922539925444604e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.86
# Maximo valor en la aceleracion:  211224928.04729816
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.130324144480159e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.87
# Maximo valor en la aceleracion:  212806417.84920934
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.1358575399617833e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.88
# Maximo valor en la aceleracion:  212737639.88146362
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.123349264528476e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.89
# Maximo valor en la aceleracion:  212738917.0517401
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.1654449016686955e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9
# Maximo valor en la aceleracion:  213385372.63832116
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.114177427757116e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.91
# Maximo valor en la aceleracion:  302276301.6015073
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.1675755532421737e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.92
# Maximo valor en la aceleracion:  209906648.19643325
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.240849154015718e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.93
# Maximo valor en la aceleracion:  206326202.10098973
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.2167682991000755e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9400000000000001
# Maximo valor en la aceleracion:  204880367.6264285
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.2151995181232627e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9500000000000001
# Maximo valor en la aceleracion:  207161879.94848162
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.278537057650813e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9600000000000001
# Maximo valor en la aceleracion:  209413791.00991726
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.298242568851035e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9700000000000001
# Maximo valor en la aceleracion:  210930944.08900762
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.346326755702218e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9800000000000001
# Maximo valor en la aceleracion:  211939547.279172
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.3760238426948794e-23  Joules.
#
#
# Tiempo actual en la simulacion! :  0.9900000000000001
# Maximo valor en la aceleracion:  212433352.90470988
# Minimo valor en la aceleracion:  0.0
# Energia promedio del sistema:  3.4339695073948833e-23  Joules.
#
#
# Time taken with guvectorize (parallel): 0.061160 seconds
